# %% [markdown]
# <center>
#     <a href="https://cognitiveclass.ai"><img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%204/images/IDSNlogo.png" width = 300> </a>
# </center>
#
# # From Modeling to Evaluation
#
# Estimated time needed: **20** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# -   Create Models
# -   Evaluate the models

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1.  [Recap](#0)<br>
# 2.  [Data Modeling](#2)<br>
# 3.  [Model Evaluation](#4)<br>
#     </div>
#     <hr>

# %% [markdown]
# # Recap <a id="0"></a>
#
# In Lab **From Understanding to Preparation**, we explored the data and prepared it for modeling.

# %% [markdown]
# The data was compiled by a researcher named Yong-Yeol Ahn, who scraped tens of thousands of food recipes (cuisines and ingredients) from three different websites, namely:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%202/images/lab2_fig3_allrecipes.png" width=500>
# <div align="center">
# www.allrecipes.com
# </div>
# <br/><br/>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%202/images/lab2_fig4_epicurious.png" width=500>
# <div align="center">
# www.epicurious.com
# </div>
# <br/><br/>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%202/images/lab2_fig5_menupan.png" width=500>
# <div align="center">
# www.menupan.com
# </div>
# <br/><br/>

# %% [markdown]
# For more information on Yong-Yeol Ahn and his research, you can read his paper on [Flavor Network and the Principles of Food Pairing](http://yongyeol.com/papers/ahn-flavornet-2011.pdf?utm_email=Email&utm_source=Nurture&utm_content=000026UJ&utm_term=10006555&utm_campaign=PLACEHOLDER&utm_id=SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork-20083987).

# %% [markdown]
# <strong>Important note:</strong> Please note that you are not expected to know how to program in python. The following code is meant to illustrate the stage of data collection, so it is totally fine if you do not understand the individual lines of code. There will be a full course in this certificate on programming in python, <a href="http://cocl.us/PY0101EN_DS0103EN_LAB4_PYTHON_edX">Python for Data Science</a>, which will teach you how to program in Python if you decide to complete this certificate.

# %% [markdown]
# ### Using this notebook:
#
# To run any of the following cells of code, you can type **Shift + Enter** to excute the code in a cell.

# %% [markdown]
# Download the library and dependencies that we will need to run this lab.

# %%
import pandas as pd # import library to read data into dataframe
pd.set_option("display.max_columns", None)
import numpy as np # import numpy library
import re # import library for regular expression
import random # library for random number generation

# %% [markdown]
# We already placed the data on an IBM server for your convenience, so let's download it from server and read it into a dataframe called **recipes**.

# %%
recipes = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%202/recipes.csv")

print("Data read into dataframe!") # takes about 30 seconds
# Out:
# Data read into dataframe!

# %% [markdown]
# We will repeat the preprocessing steps that we implemented in Lab **From Understanding to Preparation** in order to prepare the data for modeling. For more details on preparing the data, please refer to Lab **From Understanding to Preparation**.

# %%
# fix name of the column displaying the cuisine
column_names = recipes.columns.values
column_names[0] = "cuisine"
recipes.columns = column_names

# convert cuisine names to lower case
recipes["cuisine"] = recipes["cuisine"].str.lower()

# make the cuisine names consistent
recipes.loc[recipes["cuisine"] == "austria", "cuisine"] = "austrian"
recipes.loc[recipes["cuisine"] == "belgium", "cuisine"] = "belgian"
recipes.loc[recipes["cuisine"] == "china", "cuisine"] = "chinese"
recipes.loc[recipes["cuisine"] == "canada", "cuisine"] = "canadian"
recipes.loc[recipes["cuisine"] == "netherlands", "cuisine"] = "dutch"
recipes.loc[recipes["cuisine"] == "france", "cuisine"] = "french"
recipes.loc[recipes["cuisine"] == "germany", "cuisine"] = "german"
recipes.loc[recipes["cuisine"] == "india", "cuisine"] = "indian"
recipes.loc[recipes["cuisine"] == "indonesia", "cuisine"] = "indonesian"
recipes.loc[recipes["cuisine"] == "iran", "cuisine"] = "iranian"
recipes.loc[recipes["cuisine"] == "italy", "cuisine"] = "italian"
recipes.loc[recipes["cuisine"] == "japan", "cuisine"] = "japanese"
recipes.loc[recipes["cuisine"] == "israel", "cuisine"] = "jewish"
recipes.loc[recipes["cuisine"] == "korea", "cuisine"] = "korean"
recipes.loc[recipes["cuisine"] == "lebanon", "cuisine"] = "lebanese"
recipes.loc[recipes["cuisine"] == "malaysia", "cuisine"] = "malaysian"
recipes.loc[recipes["cuisine"] == "mexico", "cuisine"] = "mexican"
recipes.loc[recipes["cuisine"] == "pakistan", "cuisine"] = "pakistani"
recipes.loc[recipes["cuisine"] == "philippines", "cuisine"] = "philippine"
recipes.loc[recipes["cuisine"] == "scandinavia", "cuisine"] = "scandinavian"
recipes.loc[recipes["cuisine"] == "spain", "cuisine"] = "spanish_portuguese"
recipes.loc[recipes["cuisine"] == "portugal", "cuisine"] = "spanish_portuguese"
recipes.loc[recipes["cuisine"] == "switzerland", "cuisine"] = "swiss"
recipes.loc[recipes["cuisine"] == "thailand", "cuisine"] = "thai"
recipes.loc[recipes["cuisine"] == "turkey", "cuisine"] = "turkish"
recipes.loc[recipes["cuisine"] == "vietnam", "cuisine"] = "vietnamese"
recipes.loc[recipes["cuisine"] == "uk-and-ireland", "cuisine"] = "uk-and-irish"
recipes.loc[recipes["cuisine"] == "irish", "cuisine"] = "uk-and-irish"


# remove data for cuisines with < 50 recipes:
recipes_counts = recipes["cuisine"].value_counts()
cuisines_indices = recipes_counts > 50

cuisines_to_keep = list(np.array(recipes_counts.index.values)[np.array(cuisines_indices)])
recipes = recipes.loc[recipes["cuisine"].isin(cuisines_to_keep)]

# convert all Yes's to 1's and the No's to 0's
recipes = recipes.replace(to_replace="Yes", value=1)
recipes = recipes.replace(to_replace="No", value=0)

# %% [markdown]
# <hr>

# %% [markdown]
# # Data Modeling <a id="2"></a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%204/images/flowchart_data_modeling.png" width=500>

# %% [markdown]
# Download and install more libraries and dependencies to build decision trees.

# %%
# import decision trees scikit-learn libraries
# %matplotlib inline
from sklearn import tree
from sklearn.metrics import accuracy_score, confusion_matrix

import matplotlib.pyplot as plt

# !conda install python-graphviz --yes
import graphviz

from sklearn.tree import export_graphviz

import itertools
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                       /                                                         failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - alabaster -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - anaconda==2021.05 -> python[version='3.7.10|3.9.4|3.8.8',build='h88f2d9e_0|h88f2d9e_5']
#   - appdirs -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - argon2-cffi -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - astroid -> python[version='>=3.10,<3.11.0a0']
#   - atomicwrites -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - attrs -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - autopep8 -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - backports -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - backports.functools_lru_cache -> python[version='>=2.7,<2.8.0a0']
#   - bkcharts -> python[version='>=3.7.1,<3.8.0a0']
#   - brotlipy -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0']
#   - clyent -> python[version='>=3.10,<3.11.0a0']
#   - colorama -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - contextlib2 -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - cython -> python[version='>=3.10,<3.11.0a0']
#   - defusedxml -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - flake8 -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - gevent -> python[version='>=3.10,<3.11.0a0']
#   - glob2 -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - h5py -> python[version='<3']
#   - html5lib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - imageio -> python[version='>=3.9,<3.10.0a0']
#   - ipywidgets -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - isort -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - jdcal -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - jsonschema -> python[version='>=3.10,<3.11.0a0']
#   - mock -> python[version='>=3.9,<3.10.0a0']
#   - more-itertools -> python[version='>=3.9,<3.10.0a0']
#   - nose -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - numba -> python[version='3.4.*|>=3.10,<3.11.0a0']
#   - olefile -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - path -> python[version='>=2.7,<2.8.0a0']
#   - pickleshare -> python[version='>=3.9,<3.10.0a0']
#   - pyflakes -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.9,<3.10.0a0']
#   - pyrsistent -> python[version='>=3.5,<3.6.0a0']
#   - python-dateutil -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - pytz -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - qtpy -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - singledispatch -> python[version='>=3.9,<3.10.0a0']
#   - sniffio -> python[version='>=3,<3.7']
#   - sortedcollections -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - soupsieve -> python[version='>=3.5,<3.6.0a0|>=3.9,<3.10.0a0']
#   - sphinxcontrib-websupport -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - statsmodels -> python[version='>=3.7.1,<3.8.0a0']
#   - sympy -> python[version='>=3.10,<3.11.0a0']
#   - tblib -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - tifffile -> python[version='>=2.7,<2.8.0a0|>=3.9,<3.10.0a0|>=3.5,<3.6.0a0']
#   - tornado -> python[version='>=3.10,<3.11.0a0']
#   - typing_extensions -> python[version='>=3.9,<3.10.0a0']
#   - watchdog -> python[version='>=3.5,<3.6.0a0']
#   - wheel -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - wurlitzer -> python[version='<3.4']
#   - xlrd -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - xmltodict -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - yapf -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - zict -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - zope.event -> python[version='>=3.10,<3.11.0a0|>=3.5,<3.6.0a0']
#   - zope.interface -> python[version='>=3.10,<3.11.0a0']
#
# Your python: python=3.8
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package six conflicts for:
# pytables -> six
# h5py -> six
# jupyter_console -> prompt_toolkit[version='>=2.0.0,<3.1.0,!=3.0.0,!=3.0.1'] -> six[version='>=1.9.0']
# scikit-image -> six[version='>=1.7.3']
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> six[version='>=1.11.0']
# prompt-toolkit -> six[version='>=1.9.0']
# bleach -> six[version='>=1.9.0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> six[version='>=1.11.0']
# anaconda==2021.05 -> argon2-cffi==20.1.0=py37h9ed2024_1 -> six[version='>=1.11.0|>=1.12,<2|>=1.5.2|>=1.9|>=1.5']
# python-dateutil -> six[version='>=1.5']
# conda-package-handling -> six
# seaborn -> patsy -> six
# ipywidgets -> traitlets[version='>=4.3.1,<6.0.0'] -> six
# dask -> bokeh[version='>=1.0.0,!=2.0.0'] -> six[version='>=1.5.2']
# bokeh -> six[version='>=1.5.2']
# jsonschema -> six[version='>=1.11.0']
# pylint -> astroid[version='>=2.4.0,<=2.5'] -> six[version='>=1.12,<2']
# importlib_metadata -> pathlib2 -> six
# pytest -> more-itertools[version='>=4.0.0'] -> six[version='>=1.0.0,<2.0.0']
# nltk -> six
# pytest -> six[version='>=1.10.0']
# cycler -> six
# conda-content-trust -> six
# nltk -> gensim -> six[version='>=1.5.0']
# astropy -> packaging[version='>=19.0'] -> six[version='>=1.10.0']
# h5py -> unittest2 -> six[version='>=1.4']
# astroid -> six[version='>=1.12,<2']
# more-itertools -> six[version='>=1.0.0,<2.0.0']
# anaconda-navigator -> anaconda-client[version='>=1.6.14'] -> six
# bleach -> html5lib[version='>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8'] -> six[version='>=1.9']
# conda[version='>=4.10.3'] -> conda-package-handling[version='>=1.3.0'] -> six[version='>=1.5.2']
# anaconda==2021.05 -> six==1.15.0[build='py37hecd8cb5_0|py39hecd8cb5_0|py38hecd8cb5_0']
# pandas -> python-dateutil[version='>=2.7.3'] -> six[version='>=1.5']
# pyopenssl -> six[version='>=1.5.2']
# pyopenssl -> cryptography[version='>=3.3'] -> six[version='>=1.4.1']
# numexpr -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# mkl_fft -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# ipykernel -> traitlets[version='>=4.1.0,<6.0'] -> six
# singledispatch -> six
# multipledispatch -> six
# jupyter_core -> traitlets -> six
# ipython -> prompt-toolkit[version='>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0'] -> six[version='>=1.9.0']
# python-language-server -> pydocstyle[version='>=2.0.0'] -> six
# pylint -> six
# argon2-cffi -> six
# mkl-service -> six
# statsmodels -> patsy[version='>=0.5.2'] -> six
# dask-core -> packaging[version='>=20.0'] -> six
# patsy -> six
# conda-repo-cli -> python-dateutil[version='>=2.6.1'] -> six[version='>=1.5']
# bkcharts -> six[version='>=1.5.2']
# jupyterlab -> packaging -> six
# mock -> six
# html5lib -> six[version='>=1.9']
# conda-build -> six
# numba -> singledispatch -> six
# qtawesome -> six
# prompt_toolkit -> six[version='>=1.9.0']
# jupyter_server -> traitlets[version='>=4.2.1'] -> six
# zipp -> more-itertools -> six[version='>=1.0.0,<2.0.0']
# nbclient -> traitlets[version='>=4.2'] -> six
# anaconda-client -> six
# testpath -> pathlib2 -> six
# spyder -> cookiecutter[version='>=1.6.0'] -> six[version='>=1.10|>=1.11.0|>=1.5']
# pydocstyle -> six
# numpydoc -> sphinx -> six[version='>=1.5']
# conda-repo-cli -> six
# anaconda-client -> python-dateutil[version='>=2.6.1'] -> six[version='>=1.5']
# urllib3 -> cryptography[version='>=1.3.4'] -> six[version='>=1.4.1|>=1.5.2']
# jsonschema -> pyrsistent[version='>=0.14.0'] -> six
# scipy -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# sphinx -> six[version='>=1.5']
# numpy -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# pathlib2 -> six
# mkl_random -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# notebook -> argon2-cffi -> six
# cryptography -> six[version='>=1.4.1']
# traitlets -> six
# matplotlib-base -> cycler[version='>=0.10'] -> six[version='>=1.5']
# numpy-base -> mkl-service[version='>=2.3.0,<3.0a0'] -> six
# tornado -> singledispatch -> six
# conda-content-trust -> cryptography -> six[version='>=1.4.1']
# anaconda-project -> anaconda-client -> six
# jupyter_client -> python-dateutil[version='>=2.1'] -> six[version='>=1.5']
# pyrsistent -> six
# qtconsole -> traitlets -> six
# scikit-learn -> mkl-service[version='>=2,<3.0a0'] -> six
# jupyter-packaging -> packaging -> six
# pickleshare -> pathlib2 -> six
# nbconvert -> bleach -> six[version='>=1.9.0']
# matplotlib -> cycler[version='>=0.10'] -> six[version='>=1.5']
# conda-token -> conda-content-trust -> six
# bokeh -> packaging[version='>=16.8'] -> six[version='>=1.5']
# distributed -> six
# packaging -> six
#
# Package libffi conflicts for:
# appnope -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# conda[version='>=4.10.3'] -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# testpath -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# markupsafe -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# parso -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pycodestyle -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# distributed -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# bkcharts -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pip -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mistune -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# three-merge -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# asn1crypto -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# nbclient -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# itsdangerous -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pickleshare -> python[version='>=3'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# simplegeneric -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# psutil -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pydocstyle -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# numpy -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pytz -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# applaunchservices -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# json5 -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# isort -> python[version='>=3.6.1,<4.0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# wrapt -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib-devhelp -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# soupsieve -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jdcal -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# anyio -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# fsspec -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# clyent -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# ipywidgets -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib-websupport -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# lxml -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# cryptography -> cffi[version='>=1.12'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# gettext -> libffi[version='>=3.2.1,<3.3a0']
# xlwt -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# cython -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# kiwisolver -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# python-dateutil -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# intervaltree -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# cffi -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0']
# xlrd -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# python-libarchive-c -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# dbus -> glib -> libffi[version='>=3.0.0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# zict -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# ujson -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# backports.functools_lru_cache -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jupyter-packaging -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# attrs -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jupyterlab -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# chardet -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# backports.tempfile -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pytest -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# backports -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyerfa -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# gevent -> cffi[version='>=1.12.2'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# backports.weakref -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# argh -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# importlib-metadata -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# tqdm -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# boto -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# pandas -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# xmltodict -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# keyring -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# more-itertools -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# send2trash -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# textdistance -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# qtpy -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mkl_fft -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# ptyprocess -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# prometheus_client -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# gmpy2 -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# py-lief -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# greenlet -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# alabaster -> python[version='>=2.7,<2.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3a0']
# jupyterlab_server -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# bitarray -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# appscript -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# astroid -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sqlalchemy -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# wheel -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jsonschema -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# locket -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sip -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# qtawesome -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# cytoolz -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# nltk -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# black -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# sortedcontainers -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pywavelets -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# packaging -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# spyder-kernels -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# urllib3 -> python[version='>=3.6,<4.0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyyaml -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# threadpoolctl -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# async_generator -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# path.py -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pkginfo -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# cycler -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyls-spyder -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# typing_extensions -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# scipy -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# navigator-updater -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# py -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pygments -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# toolz -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# astropy -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# llvmlite -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# anaconda-project -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib-applehelp -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# h5py -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyopenssl -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mkl_random -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# wcwidth -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# contextlib2 -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# prompt_toolkit -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# seaborn -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# regex -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# scikit-learn -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jinja2 -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# yapf -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# python-language-server -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pytables -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib-qthelp -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# rope -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyrsistent -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# brotlipy -> cffi[version='>=1.0.0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# sphinx -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# path -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# html5lib -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jupyter_client -> python[version='>=3.6.1'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# tblib -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# cloudpickle -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# idna -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# fastcache -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mccabe -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# prompt-toolkit -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# babel -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# python-graphviz -> graphviz -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# qtconsole -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyodbc -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# importlib_metadata -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# unicodecsv -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pandocfilters -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# backcall -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# werkzeug -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# anaconda==2021.05 -> libffi==3.3=hb1e8313_2
# argon2-cffi -> cffi[version='>=1.0.0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# jupyter_console -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# partd -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# conda-package-handling -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sortedcollections -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pathlib2 -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# requests -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# iniconfig -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib-serializinghtml -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# xlwings -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# imagesize -> python[version='>=3.4'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mkl-service -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# filelock -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# nose -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# atomicwrites -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# patsy -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# pylint -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# future -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# singledispatch -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# click -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# watchdog -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# docutils -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# lazy-object-proxy -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# _ipyw_jlab_nb_ext_conf -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# zope.interface -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pep8 -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# heapdict -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# python.app -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# numba -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# traitlets -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# appdirs -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# wurlitzer -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# conda-repo-cli -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# bleach -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# et_xmlfile -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jupyterlab_pygments -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# cffi -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# diff-match-patch -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# scikit-image -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sympy -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# conda-content-trust -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# beautifulsoup4 -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# anaconda==2021.05 -> cffi==1.14.5=py37h2125817_0 -> libffi[version='>=3.3,<3.4.0a0']
# pathspec -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# networkx -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pluggy -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# nest-asyncio -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# numpy-base -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib-htmlhelp -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# typed-ast -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# multipledispatch -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3.0a0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# flask -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# nbclassic -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# autopep8 -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# nbformat -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pycurl -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# defusedxml -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# toml -> python[version='>=2.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# rtree -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# dask-core -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jupyter_core -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# conda-token -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mpmath -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# zope -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pycparser -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# ply -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# qdarkstyle -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# snowballstemmer -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pexpect -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mock -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# colorama -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# imageio -> python[version='>=3'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# matplotlib-base -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# backports.shutil_get_terminal_size -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# joblib -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# notebook -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# zope.event -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# anaconda-client -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# dask -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# tifffile -> python[version='>=3.7'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# ipython_genutils -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# glob2 -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyflakes -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pycosat -> python[version='>=3.8,<3.9.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# matplotlib -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# msgpack-python -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# spyder -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# decorator -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# ruamel_yaml -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# glib -> libffi[version='>=3.0.0|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# zipp -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# certifi -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# six -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# mypy_extensions -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# numpydoc -> python[version='>=3.5'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# xlsxwriter -> python[version='>=3.4'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# conda-build -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# flake8 -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pillow -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# python=3.8 -> libffi[version='>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# ipython -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# pyparsing -> python[version='>=3.6'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# statsmodels -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# python-jsonrpc-server -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# jupyter_server -> python[version='>=3.6,<3.7.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0']
# bokeh -> python[version='>=3.9,<3.10.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# openpyxl -> python -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
# anaconda-navigator -> python[version='>=3.7,<3.8.0a0'] -> libffi[version='3.2.*|>=3.2.1,<3.3a0|>=3.3,<3.4.0a0|>=3.2.1,<3.3.0a0']
#
# Package brotlipy conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.27'] -> brotlipy[version='>=0.6.0']
# anaconda==2021.05 -> urllib3==1.26.4=pyhd3eb1b0_0 -> brotlipy[version='>=0.6.0']
# urllib3 -> brotlipy[version='>=0.6.0']
# anaconda==2021.05 -> brotlipy==0.7.0[build='py38h9ed2024_1003|py39h9ed2024_1003|py37h9ed2024_1003']
#
# Package sqlite conflicts for:
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.33.0,<4.0a0|>=3.36.0,<4.0a0|>=3.35.4,<4.0a0|>=3.32.3,<4.0a0|>=3.30.0,<4.0a0']
# pylint -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.26.0,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0|>=3.27.2,<4.0a0|>=3.25.3,<4.0a0']
# applaunchservices -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# numpy -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# isort -> python[version='>=3.6.1,<4.0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# wrapt -> python[version='>=3.9,<3.10.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# soupsieve -> python[version='>=3.6'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# jdcal -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# wurlitzer -> python[version='>=3.8,<3.9.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# bleach -> python[version='>=3.6'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# h5py -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.33.0,<4.0a0|>=3.36.0,<4.0a0|>=3.35.4,<4.0a0|>=3.32.3,<4.0a0|>=3.30.0,<4.0a0']
# pyls-spyder -> python[version='>=3.6'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# sphinxcontrib-websupport -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.33.0,<4.0a0|>=3.31.1,<4.0a0|>=3.30.1,<4.0a0|>=3.29.0,<4.0a0|>=3.26.0,<4.0a0|>=3.25.2,<4.0a0|>=3.36.0,<4.0a0|>=3.27.2,<4.0a0|>=3.25.3,<4.0a0|>=3.30.0,<4.0a0|>=3.35.4,<4.0a0|>=3.32.3,<4.0a0']
# sphinxcontrib-jsmath -> python[version='>=3.5'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# pathspec -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# networkx -> python[version='>=3.7'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# python-dateutil -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# xlrd -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# python-libarchive-c -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# backports.functools_lru_cache -> python -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.32.3,<4.0a0|>=3.33.0,<4.0a0|>=3.35.4,<4.0a0|>=3.36.0,<4.0a0']
# xlwings -> python[version='>=3.7,<3.8.0a0'] -> sqlite[version='>=3.20.1,<4.0a0|>=3.22.0,<4.0a0|>=3.23.1,<4.0a0|>=3.24.0,<4.0a0|>=3.25.2,<4.0a0|>=3.25.3,<4.0a0|>=3.26.0,<4.0a0|>=3.27.2,<4.0a0|>=3.29.0,<4.0a0|>=3.30.1,<4.0a0|>=3.31.1,<4.0a0|>=3.33.0,<4.0a0|>=3.36.0,<4.0a0|>=3.35.4,<4.0a0|>=3.32.3,<4.0a0|>=3.30.0,<4.0a0']
# ...
# anaconda==2021.05 -> sip[version='4.19.13|4.19.8|4.19.8',build='py38h0a44026_0|py37h0a44026_0|py39h23ab428_0']
# anaconda-navigator -> pyqt[version='>=5.6,<6.0a0'] -> sip[version='4.18.*|4.19.13.*|>=4.19.4,<=4.19.8']
# navigator-updater -> pyqt[version='>=5.6'] -> sip[version='4.18.*|4.19.13.*|>=4.19.4,<=4.19.8']
# qtconsole -> pyqt -> sip[version='4.18.*|4.19.13.*|>=4.19.4,<=4.19.8']
#
# Package pbr conflicts for:
# pytables -> mock -> pbr
# mock -> pbr
#
# Package liblief conflicts for:
# conda-build -> py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.8.3',build='h2a1bed3_0|h2a1bed3_2|h0a44026_0|h23ab428_1|h2a1bed3_1']
# anaconda==2021.05 -> liblief==0.10.1[build='h0a44026_0|h23ab428_1']
# py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.8.3',build='h2a1bed3_0|h2a1bed3_2|h0a44026_0|h23ab428_1|h2a1bed3_1']
#
# Package py conflicts for:
# astropy -> pytest[version='<4'] -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
# anaconda==2021.05 -> pytest==6.2.3=py37hecd8cb5_2 -> py[version='>=1.8.2']
# anaconda==2021.05 -> py==1.10.0=pyhd3eb1b0_0
# pytest -> py[version='>=1.4.33|>=1.5.0|>=1.8.2']
#
# Package simplegeneric conflicts for:
# ipykernel -> ipython[version='>=5.0'] -> simplegeneric[version='>0.8']
# ipywidgets -> ipython[version='>=4.0.0'] -> simplegeneric[version='>0.8']
# anaconda==2021.05 -> simplegeneric==0.8.1[build='py37_2|py39hecd8cb5_2|py38_2']
# jupyterlab -> ipython -> simplegeneric[version='>0.8']
# jupyter_console -> ipython -> simplegeneric[version='>0.8']
# ipython -> simplegeneric[version='>0.8']
#
# Package giflib conflicts for:
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> giflib[version='>=5.1.4,<5.2.0a0']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# pillow -> libwebp[version='>=0.3.0'] -> giflib[version='>=5.1.4,<5.2.0a0|>=5.2.1,<5.3.0a0']
# anaconda==2021.05 -> giflib==5.1.4=h1de35cc_1
#
# Package tblib conflicts for:
# anaconda==2021.05 -> distributed==2021.4.0=py37hecd8cb5_0 -> tblib[version='>=1.6.0']
# dask -> distributed=2021.10.0 -> tblib[version='>=1.6.0']
# anaconda==2021.05 -> tblib==1.7.0=py_0
# distributed -> tblib[version='>=1.6.0']
#
# Package colorama conflicts for:
# anaconda==2021.05 -> colorama==0.4.4=pyhd3eb1b0_0
# numpydoc -> sphinx -> colorama[version='>=0.3.5']
# spyder -> sphinx[version='>=0.6.6'] -> colorama[version='>=0.3.5']
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> colorama[version='>=0.3.5']
# sphinx -> colorama[version='>=0.3.5']
#
# Package alabaster conflicts for:
# sphinx -> alabaster[version='>=0.7,<0.8']
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> alabaster[version='>=0.7,<0.8']
# numpydoc -> sphinx -> alabaster[version='>=0.7,<0.8']
# anaconda==2021.05 -> alabaster==0.7.12[build='pyhd3eb1b0_0|py37_0']
# spyder -> sphinx[version='>=0.6.6'] -> alabaster[version='>=0.7,<0.8']
#
# Package pympler conflicts for:
# spyder -> pympler
# attrs -> pympler
# pytest -> attrs[version='>=17.2.0'] -> pympler
#
# Package brotli conflicts for:
# matplotlib-base -> fonttools[version='>=4.22.0'] -> brotli[version='>=1.0.1']
# anaconda==2021.05 -> brotli==1.0.9=hb1e8313_2
# tifffile -> imagecodecs[version='>=2021.4.28'] -> brotli[version='>=1.0.7,<1.1.0a0|>=1.0.9,<1.1.0a0|>=1.0.9,<2.0a0']
# anaconda==2021.05 -> brunsli==0.1=h23ab428_0 -> brotli[version='>=1.0.9,<1.1.0a0|>=1.0.9,<2.0a0']
#
# Package conda-content-trust conflicts for:
# conda-token -> conda-content-trust
# anaconda-navigator -> conda-token -> conda-content-trust
#
# Package wrapt conflicts for:
# pylint -> astroid[version='>=2.6.5,<=2.7'] -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
# anaconda==2021.05 -> astroid==2.5=py37hecd8cb5_1 -> wrapt[version='>=1.11,<2']
# astroid -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
# anaconda==2021.05 -> wrapt==1.12.1[build='py38haf1e3a3_1|py39h9ed2024_1|py37h1de35cc_1']
#
# Package anaconda-project conflicts for:
# anaconda-navigator -> anaconda-project[version='>=0.4']
# anaconda==2021.05 -> anaconda-project==0.9.1=pyhd3eb1b0_1
#
# Package gmpy2 conflicts for:
# anaconda==2021.05 -> sympy==1.8=py37hecd8cb5_0 -> gmpy2[version='>=2.0.8']
# sympy -> gmpy2[version='>=2.0.8']
# anaconda==2021.05 -> gmpy2==2.0.8[build='py38h6ef4df4_3|py37h6ef4df4_2|py39h4b98818_3']
#
# Package charls conflicts for:
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> charls[version='>=2.2.0,<2.3.0a0']
# anaconda==2021.05 -> charls==2.2.0=h23ab428_0
#
# Package pysocks conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.27'] -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# anaconda==2021.05 -> pysocks==1.7.1[build='py37hecd8cb5_0|py39hecd8cb5_0|py38_1']
# anaconda==2021.05 -> urllib3==1.26.4=pyhd3eb1b0_0 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
#
# Package imageio conflicts for:
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0']
# anaconda==2021.05 -> scikit-image==0.18.1=py37hb2f4e1b_0 -> imageio[version='>=2.3.0']
# anaconda==2021.05 -> imageio==2.9.0=pyhd3eb1b0_0
#
# Package sortedcontainers conflicts for:
# distributed -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# anaconda==2021.05 -> distributed==2021.4.0=py37hecd8cb5_0 -> sortedcontainers[version='!=2.0.0,!=2.0.1|>=2.0']
# attrs -> hypothesis -> sortedcontainers[version='>=2.1.0,<3.0.0']
# anaconda==2021.05 -> sortedcontainers==2.3.0=pyhd3eb1b0_0
# spyder -> intervaltree[version='>=3.0.2'] -> sortedcontainers
# intervaltree -> sortedcontainers
# dask -> distributed=2021.10.0 -> sortedcontainers[version='!=2.0.0,!=2.0.1']
# sortedcollections -> sortedcontainers[version='>=2.0']
#
# Package flake8 conflicts for:
# python-language-server -> flake8[version='>=3.8.0']
# anaconda==2021.05 -> python-language-server==0.36.2=pyhd3eb1b0_0 -> flake8[version='>=3.8.0']
# pyls-black -> python-language-server -> flake8[version='>=3.8.0']
# spyder -> python-lsp-server[version='>=1.2.2,<1.3.0'] -> flake8[version='>=3.8.0|>=3.8.0,<4.0.0']
# anaconda==2021.05 -> flake8==3.9.0=pyhd3eb1b0_0
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> flake8[version='>=3.8.0|>=3.8.0,<4.0.0']
#
# Package glib conflicts for:
# anaconda==2021.05 -> dbus==1.13.18=h18a8e69_0 -> glib
# anaconda==2021.05 -> glib==2.68.1=hdf23fa2_0
# dbus -> glib[version='>=2.53.6,<3.0a0|>=2.56.1,<3.0a0|>=2.56.2,<3.0a0|>=2.63.1,<3.0a0']
# python-graphviz -> graphviz -> glib[version='>=2.56.1,<3.0a0']
# pyqt -> dbus[version='>=1.13.12,<2.0a0'] -> glib[version='>=2.53.6,<3.0a0|>=2.56.1,<3.0a0|>=2.56.2,<3.0a0|>=2.63.1,<3.0a0']
#
# Package appscript conflicts for:
# xlwings -> appscript[version='>=1.0.1']
# anaconda==2021.05 -> appscript==1.1.2[build='py39h9ed2024_0|py37h9ed2024_0|py38h9ed2024_0']
# anaconda==2021.05 -> xlwings==0.23.0=py37hecd8cb5_0 -> appscript[version='>=1.0.1']
#
# Package pywavelets conflicts for:
# scikit-image -> pywavelets[version='>=0.4.0|>=1.1.1']
# anaconda==2021.05 -> scikit-image==0.18.1=py37hb2f4e1b_0 -> pywavelets[version='>=0.4.0']
# anaconda==2021.05 -> pywavelets==1.1.1[build='py37haf1e3a3_2|py39he3068b8_4|py38haf1e3a3_2']
#
# Package filelock conflicts for:
# conda-build -> filelock
# anaconda==2021.05 -> filelock==3.0.12=pyhd3eb1b0_1
#
# Package jupyterlab_launcher conflicts for:
# jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyterlab_launcher[version='>=0.10.0,<0.11.0|>=0.11.0,<0.12.0|>=0.11.2,<0.12.0|>=0.13.1,<0.14.0|>=0.6.0,<0.7.0|>=0.4.0']
#
# Package locket conflicts for:
# partd -> locket
# anaconda==2021.05 -> locket==0.2.1[build='py38hecd8cb5_1|py37hecd8cb5_1|py39hecd8cb5_1']
# anaconda==2021.05 -> partd==1.2.0=pyhd3eb1b0_0 -> locket
# dask -> partd[version='>=0.3.10'] -> locket
# dask-core -> partd[version='>=0.3.10'] -> locket
#
# Package distributed conflicts for:
# anaconda==2021.05 -> dask==2021.4.0=pyhd3eb1b0_0 -> distributed[version='>=2021.4.0']
# anaconda==2021.05 -> distributed==2021.4.0[build='py37hecd8cb5_0|py39hecd8cb5_0|py38hecd8cb5_0']
# scikit-image -> dask[version='>=0.5'] -> distributed[version='2021.10.0.*|2021.9.1.*|2021.8.1.*|2021.8.0.*|2021.7.2.*|2021.7.0.*|2021.6.2.*|2021.6.1.*|2021.6.0.*|2021.5.1.*|2021.5.0.*|2021.4.1.*|>=2021.4.0|>=2021.3.1|>=2021.3.0|>=2021.2.0|>=2021.1.1|>=2021.1.0|>=2020.12.0|>=2.30.0|>=2.29.0|>=2.27.0|>=2.26.0|>=2.25.0|>=2.24.0|>=2.23.0|>=2.22.0|>=2.20.0|>=2.19.0|>=2.18.0|>=2.17.0|>=2.16.0|>=2.15.0|>=2.14.0|>=2.13.0|>=2.12.0|>=2.11.0|>=2.10.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=2|>=1.28.0|>=1.27.0|>=1.26.1|>=1.26.0|>=1.25.3|>=1.25.0|>=1.24.2|>=1.23.3|>=1.23.2|>=1.23.1|>=1.23.0|>=1.22.0|>=1.21.0|>=1.21.1|>=1.20.0|>=1.19.0|>=1.16.0']
# dask -> distributed[version='2021.10.0.*|2021.9.1.*|2021.8.1.*|2021.8.0.*|2021.7.2.*|2021.7.0.*|2021.6.2.*|2021.6.1.*|2021.6.0.*|2021.5.1.*|2021.5.0.*|2021.4.1.*|>=2021.4.0|>=2021.3.1|>=2021.3.0|>=2021.2.0|>=2021.1.1|>=2021.1.0|>=2020.12.0|>=2.30.0|>=2.29.0|>=2.27.0|>=2.26.0|>=2.25.0|>=2.24.0|>=2.23.0|>=2.22.0|>=2.20.0|>=2.19.0|>=2.18.0|>=2.17.0|>=2.16.0|>=2.15.0|>=2.14.0|>=2.13.0|>=2.12.0|>=2.11.0|>=2.10.0|>=2.9.2|>=2.9.1|>=2.9.0|>=2.8.1|>=2.8.0|>=2.7.0|>=2.6.0|>=2.5.2|>=2.5.0|>=2.4.0|>=2.3.0|>=2.2.0|>=2|>=1.28.0|>=1.27.0|>=1.26.1|>=1.26.0|>=1.25.3|>=1.25.0|>=1.24.2|>=1.23.3|>=1.23.2|>=1.23.1|>=1.23.0|>=1.22.0|>=1.21.0|>=1.21.1|>=1.20.0|>=1.19.0|>=1.16.0']
#
# Package libspatialindex conflicts for:
# anaconda==2021.05 -> libspatialindex==1.9.3=h23ab428_0
# spyder -> rtree[version='>=0.9.7'] -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# rtree -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
# anaconda==2021.05 -> rtree==0.9.7=py37hecd8cb5_1 -> libspatialindex[version='>=1.9.3,<1.9.4.0a0']
#
# Package pyerfa conflicts for:
# astropy -> pyerfa[version='>=1.7.3|>=2.0']
# anaconda==2021.05 -> pyerfa==1.7.3[build='py39h9ed2024_0|py37h9ed2024_0|py38h9ed2024_0']
# anaconda==2021.05 -> astropy==4.2.1=py37h9ed2024_1 -> pyerfa
#
# Package contextvars conflicts for:
# distributed -> contextvars
# dask -> distributed[version='>=2021.3.0'] -> contextvars
# anyio -> sniffio[version='>=1.1'] -> contextvars[version='>=2.1']
# sniffio -> contextvars[version='>=2.1']
#
# Package spyder-kernels conflicts for:
# spyder -> spyder-kernels[version='0.*|>=0.1,<1|>=0.4.2,<1|>=0.4.3,<1|>=0.5.0,<1|>=1.10.0,<1.11.0|>=1.10.1,<1.11.0|>=1.10.2,<1.11.0|>=2.0.1,<2.1.0|>=2.0.3,<2.1.0|>=2.0.4,<2.1.0|>=2.1.1,<2.2.0|>=1.9.4,<1.10.0|>=1.9.2,<1.10.0|>=1.9.1,<1.10.0|>=1.9.0,<1.10.0|>=1.8.1,<1.9.0']
# anaconda==2021.05 -> spyder-kernels==1.10.2[build='py37hecd8cb5_0|py39hecd8cb5_0|py38hecd8cb5_0']
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> spyder-kernels[version='>=1.10.2,<1.11.0']
#
# Package path conflicts for:
# anaconda==2021.05 -> path.py==12.5.0=0 -> path
# anaconda==2021.05 -> path==15.1.2[build='py37hecd8cb5_0|py39hecd8cb5_0|py38hecd8cb5_0']
# path.py -> path[version='<13.2']
#
# Package libedit conflicts for:
# pyodbc -> unixodbc[version='>=2.3.9,<2.4.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# python=3.8 -> sqlite[version='>=3.33.0,<4.0a0'] -> libedit[version='>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# libcurl -> krb5[version='>=1.19.2,<1.20.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20210216,<3.2.0a0|>=3.1.20210216,<4.0a0|>=3.1.20191231,<4.0a0|>=3.1.20181209,<4.0a0|>=3.1.20170329,<4.0a0']
# anaconda==2021.05 -> krb5==1.18.2=h75d18d8_0 -> libedit[version='>=3.1.20191231,<3.2.0a0|>=3.1.20191231,<4.0a0']
# krb5 -> libedit[version='>=3.1,<4.0a0|>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20210216,<3.2.0a0|>=3.1.20210216,<4.0a0|>=3.1.20191231,<4.0a0|>=3.1.20181209,<4.0a0|>=3.1.20170329,<4.0a0']
# qt -> sqlite[version='>=3.25.3,<4.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# unixodbc -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# anaconda==2021.05 -> libedit==3.1.20210216=h9ed2024_1
# curl -> krb5[version='>=1.19.2,<1.20.0a0'] -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0|>=3.1.20210216,<3.2.0a0|>=3.1.20210216,<4.0a0|>=3.1.20191231,<4.0a0|>=3.1.20181209,<4.0a0|>=3.1.20170329,<4.0a0']
# sqlite -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
#
# Package jdcal conflicts for:
# anaconda==2021.05 -> openpyxl==3.0.7=pyhd3eb1b0_0 -> jdcal
# openpyxl -> jdcal
# anaconda==2021.05 -> jdcal==1.4.1=py_0
#
# Package glob2 conflicts for:
# anaconda==2021.05 -> glob2==0.7=pyhd3eb1b0_0
# conda-build -> glob2[version='>=0.6']
#
# Package py-lief conflicts for:
# anaconda==2021.05 -> py-lief==0.10.1[build='py37haf313ee_0|py39h23ab428_1|py38haf313ee_0']
# conda-build -> py-lief
#
# Package iniconfig conflicts for:
# anaconda==2021.05 -> iniconfig==1.1.1=pyhd3eb1b0_0
# astropy -> pytest -> iniconfig
# anaconda==2021.05 -> pytest==6.2.3=py37hecd8cb5_2 -> iniconfig
# pytest -> iniconfig
#
# Package jxrlib conflicts for:
# anaconda==2021.05 -> jxrlib==1.1=haf1e3a3_2
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> jxrlib[version='>=1.1,<1.2.0a0']
#
# Package networkx conflicts for:
# anaconda==2021.05 -> networkx==2.5=py_0
# anaconda==2021.05 -> scikit-image==0.18.1=py37hb2f4e1b_0 -> networkx[version='>=2.0']
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
#
# Package libwebp conflicts for:
# pillow -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# tifffile -> imagecodecs[version='>=2021.4.28'] -> libwebp[version='>=1.0.0,<1.1.0a0|>=1.2.0,<1.3.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# imageio -> pillow -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# anaconda==2021.05 -> libwebp==1.0.1=hd73b212_0
# scikit-image -> pillow[version='>=4.3.0,!=7.1.0,!=7.1.1,!=8.3.0'] -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# bokeh -> pillow[version='>=7.1.0'] -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# anaconda-navigator -> pillow -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> libwebp[version='>=1.0.0,<1.1.0a0']
#
# Package immutables conflicts for:
# sniffio -> contextvars[version='>=2.1'] -> immutables[version='>=0.9']
# distributed -> contextvars -> immutables[version='>=0.9']
#
# Package dask conflicts for:
# scikit-image -> dask[version='>=0.5']
# anaconda==2021.05 -> dask==2021.4.0=pyhd3eb1b0_0
#
# Package _low_priority conflicts for:
# python-libarchive-c -> libarchive -> _low_priority
# libarchive -> _low_priority
# conda-build -> libarchive -> _low_priority
#
# Package lerc conflicts for:
# anaconda==2021.05 -> lerc==2.2.1=h23ab428_0
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> lerc[version='>=2.2.1,<3.0a0']
#
# Package libaec conflicts for:
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> libaec[version='>=1.0.4,<2.0a0']
# anaconda==2021.05 -> libaec==1.0.4=hb1e8313_1
#
# Package rtree conflicts for:
# anaconda==2021.05 -> rtree==0.9.7[build='py38hecd8cb5_1|py37hecd8cb5_1|py39hecd8cb5_1']
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> rtree[version='>=0.8.3']
# spyder -> rtree[version='>=0.8.3|>=0.9.7']
#
# Package zfp conflicts for:
# anaconda==2021.05 -> imagecodecs==2021.3.31=py39h2ea9c00_0 -> zfp[version='>=0.5.5,<1.0a0']
# anaconda==2021.05 -> zfp==0.5.5=h23ab428_6
#
# Package pyobjc-framework-cocoa conflicts for:
# watchdog -> pyobjc-framework-cocoa[version='>=4.2.2']
# watchdog -> pyobjc-framework-fsevents[version='>=4.2.2'] -> pyobjc-framework-cocoa[version='>=6.1|>=6.2.1|>=6.2.2']
#
# Package keyring conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py37hecd8cb5_0 -> keyring[version='>=17.0.0']
# anaconda==2021.05 -> keyring==22.3.0[build='py37hecd8cb5_0|py39hecd8cb5_0|py38hecd8cb5_0']
# spyder -> keyring[version='>=17.0.0']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-d975e5740efc> in <module>
#       7
#       8 get_ipython().system('conda install python-graphviz --yes')
# ----> 9 import graphviz
#      10
#      11 from sklearn.tree import export_graphviz
#
# ModuleNotFoundError: No module named 'graphviz'

# %% [markdown]
# Check the data again!

# %%
recipes.head()

# %% [markdown]
# ## [bamboo_tree] Only Asian and Indian Cuisines
#
# Here, we are creating a decision tree for the recipes for just some of the Asian (Korean, Japanese, Chinese, Thai) and Indian cuisines. The reason for this is because the decision tree does not run well when the data is biased towards one cuisine, in this case American cuisines. One option is to exclude the American cuisines from our analysis or just build decision trees for different subsets of the data. Let's go with the latter solution.

# %% [markdown]
# Let's build our decision tree using the data pertaining to the Asian and Indian cuisines and name our decision tree _bamboo_tree_.

# %%
# select subset of cuisines
asian_indian_recipes = recipes[recipes.cuisine.isin(["korean", "japanese", "chinese", "thai", "indian"])]
cuisines = asian_indian_recipes["cuisine"]
ingredients = asian_indian_recipes.iloc[:,1:]

bamboo_tree = tree.DecisionTreeClassifier(max_depth=3)
bamboo_tree.fit(ingredients, cuisines)

print("Decision tree model saved to bamboo_tree!")

# %% [markdown]
# Let's plot the decision tree and examine how it looks like.

# %%
export_graphviz(bamboo_tree,
                feature_names=list(ingredients.columns.values),
                out_file="bamboo_tree.dot",
                class_names=np.unique(cuisines),
                filled=True,
                node_ids=True,
                special_characters=True,
                impurity=False,
                label="all",
                leaves_parallel=False)

with open("bamboo_tree.dot") as bamboo_tree_image:
    bamboo_tree_graph = bamboo_tree_image.read()
graphviz.Source(bamboo_tree_graph)

# %% [markdown]
# The decision tree learned:
#
# -   If a recipe contains _cumin_ and _fish_ and **no** _yoghurt_, then it is most likely a **Thai** recipe.
# -   If a recipe contains _cumin_ but **no** _fish_ and **no** _soy_sauce_, then it is most likely an **Indian** recipe.

# %% [markdown]
# You can analyze the remaining branches of the tree to come up with similar rules for determining the cuisine of different recipes.

# %% [markdown]
# Feel free to select another subset of cuisines and build a decision tree of their recipes. You can select some European cuisines and build a decision tree to explore the ingredients that differentiate them.

# %% [markdown]
# # Model Evaluation <a id="4"></a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%204/images/flowchart_evaluation.png" width=500>

# %% [markdown]
# To evaluate our model of Asian and Indian cuisines, we will split our dataset into a training set and a test set. We will build the decision tree using the training set. Then, we will test the model on the test set and compare the cuisines that the model predicts to the actual cuisines.

# %% [markdown]
# Let's first create a new dataframe using only the data pertaining to the Asian and the Indian cuisines, and let's call the new dataframe **bamboo**.

# %%
bamboo = recipes[recipes.cuisine.isin(["korean", "japanese", "chinese", "thai", "indian"])]

# %% [markdown]
# Let's see how many recipes exist for each cuisine.

# %%
bamboo["cuisine"].value_counts()

# %% [markdown]
# Let's remove 30 recipes from each cuisine to use as the test set, and let's name this test set **bamboo_test**.

# %%
# set sample size
sample_n = 30

# %% [markdown]
# Create a dataframe containing 30 recipes from each cuisine, selected randomly.

# %%
# take 30 recipes from each cuisine
random.seed(1234) # set random seed
bamboo_test = bamboo.groupby("cuisine", group_keys=False).apply(lambda x: x.sample(sample_n))

bamboo_test_ingredients = bamboo_test.iloc[:,1:] # ingredients
bamboo_test_cuisines = bamboo_test["cuisine"] # corresponding cuisines or labels

# %% [markdown]
# Check that there are 30 recipes for each cuisine.

# %%
# check that we have 30 recipes from each cuisine
bamboo_test["cuisine"].value_counts()

# %% [markdown]
# Next, let's create the training set by removing the test set from the **bamboo** dataset, and let's call the training set **bamboo_train**.

# %%
bamboo_test_index = bamboo.index.isin(bamboo_test.index)
bamboo_train = bamboo[~bamboo_test_index]

bamboo_train_ingredients = bamboo_train.iloc[:,1:] # ingredients
bamboo_train_cuisines = bamboo_train["cuisine"] # corresponding cuisines or labels

# %% [markdown]
# Check that there are 30 _fewer_ recipes now for each cuisine.

# %%
bamboo_train["cuisine"].value_counts()

# %% [markdown]
# Let's build the decision tree using the training set, **bamboo_train**, and name the generated tree **bamboo_train_tree** for prediction.

# %%
bamboo_train_tree = tree.DecisionTreeClassifier(max_depth=15)
bamboo_train_tree.fit(bamboo_train_ingredients, bamboo_train_cuisines)

print("Decision tree model saved to bamboo_train_tree!")

# %% [markdown]
# Let's plot the decision tree and explore it.

# %%
export_graphviz(bamboo_train_tree,
                feature_names=list(bamboo_train_ingredients.columns.values),
                out_file="bamboo_train_tree.dot",
                class_names=np.unique(bamboo_train_cuisines),
                filled=True,
                node_ids=True,
                special_characters=True,
                impurity=False,
                label="all",
                leaves_parallel=False)

with open("bamboo_train_tree.dot") as bamboo_train_tree_image:
    bamboo_train_tree_graph = bamboo_train_tree_image.read()
graphviz.Source(bamboo_train_tree_graph)

# %% [markdown]
# Now that we defined our tree to be deeper, more decision nodes are generated.

# %% [markdown]
# #### Now let's test our model on the test data.

# %%
bamboo_pred_cuisines = bamboo_train_tree.predict(bamboo_test_ingredients)

# %% [markdown]
# To quantify how well the decision tree is able to determine the cuisine of each recipe correctly, we will create a confusion matrix which presents a nice summary on how many recipes from each cuisine are correctly classified. It also sheds some light on what cuisines are being confused with what other cuisines.

# %% [markdown]
# So let's go ahead and create the confusion matrix for how well the decision tree is able to correctly classify the recipes in **bamboo_test**.

# %%
test_cuisines = np.unique(bamboo_test_cuisines)
bamboo_confusion_matrix = confusion_matrix(bamboo_test_cuisines, bamboo_pred_cuisines, test_cuisines)
title = 'Bamboo Confusion Matrix'
cmap = plt.cm.Blues

plt.figure(figsize=(8, 6))
bamboo_confusion_matrix = (
    bamboo_confusion_matrix.astype('float') / bamboo_confusion_matrix.sum(axis=1)[:, np.newaxis]
    ) * 100

plt.imshow(bamboo_confusion_matrix, interpolation='nearest', cmap=cmap)
plt.title(title)
plt.colorbar()
tick_marks = np.arange(len(test_cuisines))
plt.xticks(tick_marks, test_cuisines)
plt.yticks(tick_marks, test_cuisines)

fmt = '.2f'
thresh = bamboo_confusion_matrix.max() / 2.
for i, j in itertools.product(range(bamboo_confusion_matrix.shape[0]), range(bamboo_confusion_matrix.shape[1])):
    plt.text(j, i, format(bamboo_confusion_matrix[i, j], fmt),
             horizontalalignment="center",
             color="white" if bamboo_confusion_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %% [markdown]
# After running the above code, you should get a confusion matrix similar to the following:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%204/images/lab4_fig6_confusion_matrix.png" width=500>

# %% [markdown]
# The rows represent the actual cuisines from the dataset and the columns represent the predicted ones. Each row should sum to 100%. According to this confusion matrix, we make the following observations:
#
# -   Using the first row in the confusion matrix, 60% of the **Chinese** recipes in **bamboo_test** were correctly classified by our decision tree whereas 37% of the **Chinese** recipes were misclassified as **Korean** and 3% were misclassified as **Indian**.
#
# -   Using the Indian row, 77% of the **Indian** recipes in **bamboo_test** were correctly classified by our decision tree and 3% of the **Indian** recipes were misclassified as **Chinese** and 13% were misclassified as **Korean** and 7% were misclassified as **Thai**.

# %% [markdown]
# **Please note** that because decision trees are created using random sampling of the datapoints in the training set, then you may not get the same results every time you create the decision tree even using the same training set. The performance should still be comparable though! So don't worry if you get slightly different numbers in your confusion matrix than the ones shown above.

# %% [markdown]
# Using the reference confusion matrix, how many **Japanese** recipes were correctly classified by our decision tree?

# %% [raw]
# Your Answer:

# %% [markdown]
# <details><summary>Click here for a solution</summary>
#
# ```python
#     #The correct answer is:
#     36.67%.
# ```
#
# </details>

# %% [markdown]
# Also using the reference confusion matrix, how many **Korean** recipes were misclassified as **Japanese**?

# %% [raw]
# Your Answer:

# %% [markdown]
# <details><summary>Click here for a solution</summary>
#
# ```python
#     #The correct answer is:
#      3.33%.
# ```
#
# </details>

# %% [markdown]
# What cuisine has the least number of recipes correctly classified by the decision tree using the reference confusion matrix?

# %% [raw]
# Your Answer:

# %% [markdown]
# <details><summary>Click here for a solution</summary>
#
# ```python
#     #The correct answer is:
#      Japanese cuisine, with 36.67% only.
# ```
#
# </details>

# %% [markdown]
# <br>
# <hr>

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook is part of a course called _The Data Science Method_. If you accessed this notebook outside the course, you can take this course, online by clicking [here](https://cocl.us/DS0103EN-Exercise-From-Modeling-to-Evaluation).
#
# ## Author
#
# <a href="https://www.linkedin.com/in/aklson/" target="_blank">Alex Aklson</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2021-04-06        | 2.2     | Malika     | Updated Dataset link               |
# | 2020-09-25        | 2.1     | Lakshmi    | Fixed Typo errors                  |
# | 2020-08-27        | 2.0     | Lavanya    | Moved lab to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
